# %%
# Libs
#torch"
import torch.nn as nn
import torch
import torch.optim as optim
import torch.nn.functional as F
import logging
import pandas as pd
from collections import OrderedDict
import pickle
import numpy as np
import seaborn as sns
import datetime
import os
import random
import glob
import matplotlib.pyplot as plt
from functools import reduce
# Own Modules
from source_torch.mlca.mlca_setup import set_value_model_parameters
from source_torch.mlca.mlca import mlca_mechanism
from source_torch.util import save_result,load_result
# Out:
# MLCA NN Class imported
# MLCA NN_MIP Class imported
# WDP Class imported
# MLCA_Economies imported
# MLCA function imported

# %%
# log debug to console
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s:               %(message)s', datefmt='%H:%M:%S')
device0='cuda'
torch.cuda.is_available()
dirname = './experiments/MLCA/Torch/results'

# %%
#Preparations
# model_name_1 = dirname + '/GSVM_unif'#LSVM MRVM GSVM
# model_name_2 = dirname + '/LSVM_unif'
# model_name_3 = dirname + '/MRVM_unif'
# model_name_4 = dirname + '/GSVM_gali'
# model_name_5 = dirname + '/LSVM_gali'
# model_name_6 = dirname + '/MRVM_gali'
#add all folders from dirname to a list
models = []

for root, dirs, files in os.walk(dirname):
    if dirs:
        for fold in dirs:
            models.append(dirname + '/' + fold)

print(models)
def find_files(directory):
    results = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            res = load_result((os.path.join(root, file)))
            results.append(res)
            print(res['SEED TRUE VALUES']['Seed'])
    return results


results = {}
for path in models:
    res = find_files(path)
    if res:
        results[path] = res
# Out:
# ['./experiments/MLCA/Torch/results/GSVM_unif', './experiments/MLCA/Torch/results/MRVM_unif', './experiments/MLCA/Torch/results/LSVM_gali', './experiments/MLCA/Torch/results/GSVM_galo', './experiments/MLCA/Torch/results/LSVM_unif', './experiments/MLCA/Torch/results/GSVM_gali']
# ./experiments/MLCA/Torch/results/GSVM_unif/results_2 is loaded
# 2
# ./experiments/MLCA/Torch/results/GSVM_unif/7_23_20_33_8 is loaded
# 9
# ./experiments/MLCA/Torch/results/GSVM_unif/7_23_19_42_6 is loaded
# 7
# ./experiments/MLCA/Torch/results/GSVM_unif/7_19_14_34_5 is loaded
# 5
# ./experiments/MLCA/Torch/results/GSVM_unif/results_1 is loaded
# 1
# ./experiments/MLCA/Torch/results/GSVM_unif/results_4 is loaded
# 4
# ./experiments/MLCA/Torch/results/GSVM_unif/results_0 is loaded
# 0
# ./experiments/MLCA/Torch/results/GSVM_unif/7_23_20_8_7 is loaded
# 8
# ./experiments/MLCA/Torch/results/GSVM_unif/results_3 is loaded
# 3
# ./experiments/MLCA/Torch/results/GSVM_unif/7_23_19_19_5 is loaded
# 6
# ./experiments/MLCA/Torch/results/MRVM_unif/7_26_3_33_4 is loaded
# 4
# ./experiments/MLCA/Torch/results/MRVM_unif/results_1 is loaded
# 1
# ./experiments/MLCA/Torch/results/MRVM_unif/7_25_17_11_3 is loaded
# 3
# ./experiments/MLCA/Torch/results/MRVM_unif/results_0 is loaded
# 0
# ./experiments/MLCA/Torch/results/MRVM_unif/7_20_2_45_2 is loaded
# 2
# ./experiments/MLCA/Torch/results/MRVM_unif/7_19_16_47_1 is loaded
# 1
# ./experiments/MLCA/Torch/results/LSVM_gali/7_23_0_52_13 is loaded
# 14
# ./experiments/MLCA/Torch/results/LSVM_gali/7_22_21_29_4 is loaded
# 5
# ./experiments/MLCA/Torch/results/LSVM_gali/7_23_0_7_11 is loaded
# 12
# ./experiments/MLCA/Torch/results/LSVM_gali/7_22_22_32_6 is loaded
# 7
# ./experiments/MLCA/Torch/results/LSVM_gali/results_1 is loaded
# 1
# ./experiments/MLCA/Torch/results/LSVM_gali/7_22_22_14_5 is loaded
# 6
# ./experiments/MLCA/Torch/results/LSVM_gali/results_0 is loaded
# 0
# ./experiments/MLCA/Torch/results/LSVM_gali/7_22_21_2_3 is loaded
# 4
# ./experiments/MLCA/Torch/results/LSVM_gali/7_22_22_51_7 is loaded
# 8
# ./experiments/MLCA/Torch/results/LSVM_gali/7_22_23_27_9 is loaded
# 10
# ./experiments/MLCA/Torch/results/GSVM_galo/7_22_14_33_3 is loaded
# 3
# ./experiments/MLCA/Torch/results/LSVM_unif/7_23_21_20_6 is loaded
# 7
# ./experiments/MLCA/Torch/results/LSVM_unif/results_5 is loaded
# 5
# ./experiments/MLCA/Torch/results/LSVM_unif/7_23_21_7_5 is loaded
# 6
# ./experiments/MLCA/Torch/results/LSVM_unif/7_23_21_49_9 is loaded
# 10
# ./experiments/MLCA/Torch/results/LSVM_unif/results_1 is loaded
# 1
# ./experiments/MLCA/Torch/results/LSVM_unif/results_4 is loaded
# 4
# ./experiments/MLCA/Torch/results/LSVM_unif/results_0 is loaded
# 0
# ./experiments/MLCA/Torch/results/LSVM_unif/7_23_21_32_7 is loaded
# 8
# ./experiments/MLCA/Torch/results/LSVM_unif/7_23_22_1_10 is loaded
# 11
# ./experiments/MLCA/Torch/results/LSVM_unif/7_23_21_38_8 is loaded
# 9
# ./experiments/MLCA/Torch/results/GSVM_gali/7_22_18_48_9 is loaded
# 10
# ./experiments/MLCA/Torch/results/GSVM_gali/results_2 is loaded
# 2
# ./experiments/MLCA/Torch/results/GSVM_gali/results_1 is loaded
# 1
# ./experiments/MLCA/Torch/results/GSVM_gali/7_22_17_16_5 is loaded
# 6
# ./experiments/MLCA/Torch/results/GSVM_gali/7_22_16_42_4 is loaded
# 5
# ./experiments/MLCA/Torch/results/GSVM_gali/7_22_19_47_11 is loaded
# 12
# ./experiments/MLCA/Torch/results/GSVM_gali/7_22_16_16_3 is loaded
# 4
# ./experiments/MLCA/Torch/results/GSVM_gali/7_22_18_13_8 is loaded
# 9
# ./experiments/MLCA/Torch/results/GSVM_gali/7_22_19_12_10 is loaded
# 11
# ./experiments/MLCA/Torch/results/GSVM_gali/7_22_17_50_7 is loaded
# 8

# %%
results.keys()
# Out:
# dict_keys(['./experiments/MLCA/Torch/results/GSVM_unif', './experiments/MLCA/Torch/results/MRVM_unif', './experiments/MLCA/Torch/results/LSVM_gali', './experiments/MLCA/Torch/results/LSVM_unif', './experiments/MLCA/Torch/results/GSVM_gali'])

# %%
for i in results.keys():
    print(i + ': ')
    #average MLCA Efficiency of all runs
    print('Average MLCA Efficiency: ' + str(np.mean([results[i][j]['MLCA Efficiency'] for j in range(len(results[i]))])))
    #average number of iterations of all runs
    print('Average Number of Iterations: ' + str(np.mean([len(results[i][j]['Statistics']['Efficiency per Iteration']) for j in range(len(results[i]))])))
    #Total time elapsed of all runs
    print('Total Time Elapsed for an instance: ' + str([results[i][j]['Statistics']['Total Time Elapsed'] for j in range(len(results[i]))]))
# Out:
# ./experiments/MLCA/Torch/results/GSVM_unif:
# Average MLCA Efficiency: 0.9621129388698776
# Average Number of Iterations: 3.0
# Total Time Elapsed for an instance: ['0d 0h:29m:28s', '0d 0h:27m:0s', '0d 0h:26m:39s', '0d 0h:27m:45s', '0d 0h:28m:27s', '0d 0h:27m:5s', '0d 1h:2m:30s', '0d 0h:25m:0s', '0d 0h:24m:14s', '0d 0h:22m:25s']
# ./experiments/MLCA/Torch/results/MRVM_unif:
# Average MLCA Efficiency: 0.913116928795442
# Average Number of Iterations: 7.0
# Total Time Elapsed for an instance: ['0d 4h:40m:25s', '0d 4h:25m:44s', '0d 5h:47m:16s', '0d 6h:53m:10s', '0d 3h:23m:9s', '0d 3h:48m:15s']
# ./experiments/MLCA/Torch/results/LSVM_gali:
# Average MLCA Efficiency: 0.9548210085569165
# Average Number of Iterations: 2.0
# Total Time Elapsed for an instance: ['0d 0h:19m:11s', '0d 0h:45m:32s', '0d 0h:22m:13s', '0d 0h:19m:50s', '0d 0h:24m:0s', '0d 0h:17m:9s', '0d 0h:19m:42s', '0d 0h:26m:50s', '0d 0h:13m:50s', '0d 0h:19m:6s']
# ./experiments/MLCA/Torch/results/GSVM_galo:
# Average MLCA Efficiency: 0.973114632883659
# Average Number of Iterations: 3.0
# Total Time Elapsed for an instance: ['0d 0h:37m:5s']
# ./experiments/MLCA/Torch/results/LSVM_unif:
# Average MLCA Efficiency: 0.8630275865266643
# Average Number of Iterations: 2.0
# Total Time Elapsed for an instance: ['0d 0h:11m:47s', '0d 0h:28m:14s', '0d 0h:13m:5s', '0d 0h:12m:24s', '0d 0h:23m:9s', '0d 0h:20m:21s', '0d 1h:14m:18s', '0d 0h:6m:20s', '0d 0h:11m:17s', '0d 0h:10m:22s']
# ./experiments/MLCA/Torch/results/GSVM_gali:
# Average MLCA Efficiency: 0.9898121556653777
# Average Number of Iterations: 3.0
# Total Time Elapsed for an instance: ['0d 0h:24m:5s', '0d 0h:24m:50s', '0d 0h:36m:56s', '0d 0h:20m:21s', '0d 0h:34m:28s', '0d 0h:25m:35s', '0d 0h:25m:28s', '0d 0h:34m:48s', '0d 0h:35m:32s', '0d 0h:23m:19s']

# %%
#function to efficiency for different models
def plot_efficiency(results):
    types = results.keys()
    df = pd.DataFrame(columns=['Efficiency', 'Type'])
    for i in results.keys():
        # get mean efficiency
        eff = np.mean([results[i][j]['MLCA Efficiency'] for j in range(len(results[i]))])
        df = df.append({'Efficiency': eff, 'Type': i}, ignore_index=True)
    
    sns.set(style="whitegrid")
    g = sns.catplot(
    data=df, kind="bar",
    x="Type", y="Efficiency", palette="dark", alpha=.6, height=6
    )
    # hue="something additional on the right"
    #errorbar="Standard Deviation"
    #g.despine(left=True)
    g.set_axis_labels("", "Efficiency")

def plot_efficiency_per_round(results):
    types = results.keys()
    #get mean efficiency per round
     
    df = pd.DataFrame(columns=['Iteration', 'Efficiency', 'Type'])
    for i in results.keys():
        for j in range(len(results[i]['Statistics']['Efficiency per Iteration'])):
            eff = np.mean([results[i][k]['Statistics']['Efficiency per Iteration'][j] for k in range(len(results[i]))])
            df = df.append({'Iteration': j, 'Efficiency': eff, 'Type': i}, ignore_index=True)
    
    sns.set_theme(style="darkgrid")
    sns.lineplot(x="Iteration", y="Efficiency",
             data=df, hue = 'Type')
    # Get the current axes object
    ax = plt.gca()

    # Set custom steps for the x-axis ticks
    custom_ticks = np.arange(0, np.max(df['Iteration'])+1, 1)  # Custom steps: start=0, stop=10, step=2
    ax.set_xticks(custom_ticks)

# %%
#plot_efficiency_per_round(results)
plot_efficiency(results)
# Out:
# 15:52:09:               findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0.
# 15:52:09:               findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal bold normal>) = 2.335
# 15:52:09:               findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 3.05
# 15:52:09:               findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal bold normal>) = 3.335
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 2.05
# 15:52:09:               findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant8-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Nimbus Roman' (NimbusRoman-BoldItalic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Regular.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-regular.otf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman12-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Nimbus Sans' (NimbusSans-Regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed-Italic.ttf) italic normal 400 condensed>) = 11.25
# 15:52:09:               findfont: score(<Font 'Nimbus Mono PS' (NimbusMonoPS-Regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman6-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans9-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-SemiboldItalic.ttf) italic normal semibold normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'P052' (P052-Italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Standard Symbols PS' (StandardSymbolsPS.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'URW Gothic' (URWGothic-DemiOblique.otf) oblique normal demi normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono' (lmmono8-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Liberation Mono' (LiberationMono-Bold.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Light.ttf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant10-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-oblique.otf) oblique normal 700 normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman10-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light Cond' (lmmonoltcond10-regular.otf) normal normal light condensed>) = 10.44
# 15:52:09:               findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'URW Bookman' (URWBookman-Light.otf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-boldoblique.otf) oblique normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'URW Bookman' (URWBookman-Demi.otf) normal normal book normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop' (lmmonoprop10-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'C059' (C059-Roman.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Slanted' (lmmonoslant10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono' (lmmono10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-HeavyItalic.ttf) italic normal heavy normal>) = 11.43
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-oblique.otf) oblique normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-Italic.ttf) italic normal 400 condensed>) = 11.25
# 15:52:09:               findfont: score(<Font 'Nimbus Mono PS' (NimbusMonoPS-Bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed-Bold.ttf) normal normal bold condensed>) = 10.535
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Caps' (lmmonocaps10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman9-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'C059' (C059-Italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'URW Bookman' (URWBookman-DemiItalic.otf) italic normal book normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Caps' (lmromancaps10-oblique.otf) oblique normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-boldoblique.otf) oblique normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Chorus' (texgyrechorus-mediumitalic.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-Bold.ttf) normal normal bold condensed>) = 10.535
# 15:52:09:               findfont: score(<Font 'Nimbus Sans Narrow' (NimbusSansNarrow-Bold.otf) normal normal bold condensed>) = 10.535
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Black.ttf) normal normal black normal>) = 10.525
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-BlackItalic.ttf) italic normal black normal>) = 11.525
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Demi Cond' (lmsansdemicond10-regular.otf) normal normal regular condensed>) = 10.25
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans8-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Unslanted' (lmromanunsl10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'D050000L' (D050000L.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'URW Gothic' (URWGothic-Demi.otf) normal normal demi normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman7-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Nimbus Sans Narrow' (NimbusSansNarrow-Oblique.otf) oblique normal 400 condensed>) = 11.25
# 15:52:09:               findfont: score(<Font 'Nimbus Sans Narrow' (NimbusSansNarrow-Regular.otf) normal normal 400 condensed>) = 10.25
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman7-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSans-ExtraLight.ttf) normal normal light normal>) = 2.24
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Italic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Demi' (lmromandemi10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman12-italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Demi Cond' (lmsansdemicond10-oblique.otf) oblique normal demi condensed>) = 11.44
# 15:52:09:               findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-BoldItalic.ttf) italic normal bold condensed>) = 11.535
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant12-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant17-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed.ttf) normal normal 400 condensed>) = 2.25
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans12-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans8-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-ThinItalic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Semibold.ttf) normal normal semibold normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Nimbus Roman' (NimbusRoman-Bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'TeX Gyre Pagella Math' (texgyrepagella-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Nimbus Roman' (NimbusRoman-Italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Liberation Serif' (LiberationSerif-BoldItalic.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'P052' (P052-Roman.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Math' (latinmodern-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman8-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans17-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Thin.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman5-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre DejaVu Math' (texgyredejavu-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-MediumItalic.ttf) italic normal medium normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman17-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Nimbus Mono PS' (NimbusMonoPS-Italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Bonum Math' (texgyrebonum-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'URW Bookman' (URWBookman-LightItalic.otf) italic normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed-BoldItalic.ttf) italic normal bold condensed>) = 11.535
# 15:52:09:               findfont: score(<Font 'Nimbus Sans' (NimbusSans-Italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Liberation Serif' (LiberationSerif-Bold.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman5-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono' (lmmono10-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman10-bolditalic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans9-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Nimbus Roman' (NimbusRoman-Regular.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Medium.ttf) normal normal medium normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Noto Mono' (NotoMono-Regular.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans10-boldoblique.otf) oblique normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant9-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans10-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Nimbus Mono PS' (NimbusMonoPS-BoldItalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-bold.otf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Nimbus Sans Narrow' (NimbusSansNarrow-BoldOblique.otf) oblique normal bold condensed>) = 11.535
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-LightItalic.ttf) italic normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans12-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Liberation Mono' (LiberationMono-BoldItalic.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Liberation Sans' (LiberationSans-Regular.ttf) normal normal 400 normal>) = 4.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light Cond' (lmmonoltcond10-oblique.otf) oblique normal light condensed>) = 11.44
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-boldoblique.otf) oblique normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed-BoldOblique.ttf) oblique normal bold condensed>) = 3.535
# 15:52:09:               findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-HairlineItalic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Schola Math' (texgyreschola-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Heavy.ttf) normal normal heavy normal>) = 10.43
# 15:52:09:               findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Termes Math' (texgyretermes-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman10-italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans17-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Liberation Serif' (LiberationSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Nimbus Sans' (NimbusSans-Bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans10-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Liberation Sans' (LiberationSans-Bold.ttf) normal normal bold normal>) = 4.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-oblique.otf) oblique normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'C059' (C059-Bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed-Bold.ttf) normal normal bold condensed>) = 2.535
# 15:52:09:               findfont: score(<Font 'Liberation Sans' (LiberationSans-BoldItalic.ttf) italic normal bold normal>) = 5.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop' (lmmonoprop10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'URW Gothic' (URWGothic-Book.otf) normal normal book normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'DejaVu Math TeX Gyre' (DejaVuMathTeXGyre.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman7-italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman9-italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-BoldItalic.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'P052' (P052-BoldItalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Z003' (Z003-MediumItalic.otf) italic normal medium normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Bold.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman8-italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Droid Sans Fallback' (DroidSansFallbackFull.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman9-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'C059' (C059-BdIta.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Demi' (lmromandemi10-oblique.otf) oblique normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Liberation Sans' (LiberationSans-Italic.ttf) italic normal 400 normal>) = 5.05
# 15:52:09:               findfont: score(<Font 'Liberation Mono' (LiberationMono-Regular.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-Regular.ttf) normal normal 400 condensed>) = 10.25
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman12-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono' (lmmono12-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Caps' (lmmonocaps10-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono' (lmmono9-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed.ttf) normal normal 400 condensed>) = 10.25
# 15:52:09:               findfont: score(<Font 'P052' (P052-Bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman8-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-regular.otf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Caps' (lmromancaps10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Dunhill' (lmromandunh10-oblique.otf) oblique normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman6-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Liberation Mono' (LiberationMono-Italic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Liberation Serif' (LiberationSerif-Regular.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Nimbus Sans' (NimbusSans-BoldItalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'URW Gothic' (URWGothic-BookOblique.otf) oblique normal book normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed-Oblique.ttf) oblique normal 400 condensed>) = 3.25
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Hairline.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Dunhill' (lmromandunh10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-bold.otf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0 to DejaVu Sans ('/home/artem/.conda/envs/ica_new/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 2.050000.
# 15:52:09:               findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# 15:52:09:               findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal bold normal>) = 2.335
# 15:52:09:               findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 3.05
# 15:52:09:               findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal bold normal>) = 3.335
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 2.05
# 15:52:09:               findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant8-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Nimbus Roman' (NimbusRoman-BoldItalic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Regular.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-regular.otf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman12-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Nimbus Sans' (NimbusSans-Regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed-Italic.ttf) italic normal 400 condensed>) = 11.25
# 15:52:09:               findfont: score(<Font 'Nimbus Mono PS' (NimbusMonoPS-Regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman6-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans9-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-SemiboldItalic.ttf) italic normal semibold normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'P052' (P052-Italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Standard Symbols PS' (StandardSymbolsPS.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'URW Gothic' (URWGothic-DemiOblique.otf) oblique normal demi normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono' (lmmono8-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Liberation Mono' (LiberationMono-Bold.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Light.ttf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant10-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-oblique.otf) oblique normal 700 normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman10-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light Cond' (lmmonoltcond10-regular.otf) normal normal light condensed>) = 10.44
# 15:52:09:               findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'URW Bookman' (URWBookman-Light.otf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-boldoblique.otf) oblique normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'URW Bookman' (URWBookman-Demi.otf) normal normal book normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop' (lmmonoprop10-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'C059' (C059-Roman.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Slanted' (lmmonoslant10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono' (lmmono10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-HeavyItalic.ttf) italic normal heavy normal>) = 11.43
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-oblique.otf) oblique normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-Italic.ttf) italic normal 400 condensed>) = 11.25
# 15:52:09:               findfont: score(<Font 'Nimbus Mono PS' (NimbusMonoPS-Bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed-Bold.ttf) normal normal bold condensed>) = 10.535
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Caps' (lmmonocaps10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman9-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'C059' (C059-Italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'URW Bookman' (URWBookman-DemiItalic.otf) italic normal book normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Caps' (lmromancaps10-oblique.otf) oblique normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-boldoblique.otf) oblique normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Chorus' (texgyrechorus-mediumitalic.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-Bold.ttf) normal normal bold condensed>) = 10.535
# 15:52:09:               findfont: score(<Font 'Nimbus Sans Narrow' (NimbusSansNarrow-Bold.otf) normal normal bold condensed>) = 10.535
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Black.ttf) normal normal black normal>) = 10.525
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-BlackItalic.ttf) italic normal black normal>) = 11.525
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Demi Cond' (lmsansdemicond10-regular.otf) normal normal regular condensed>) = 10.25
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans8-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Unslanted' (lmromanunsl10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'D050000L' (D050000L.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'URW Gothic' (URWGothic-Demi.otf) normal normal demi normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman7-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Nimbus Sans Narrow' (NimbusSansNarrow-Oblique.otf) oblique normal 400 condensed>) = 11.25
# 15:52:09:               findfont: score(<Font 'Nimbus Sans Narrow' (NimbusSansNarrow-Regular.otf) normal normal 400 condensed>) = 10.25
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman7-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSans-ExtraLight.ttf) normal normal light normal>) = 2.24
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Italic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Demi' (lmromandemi10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman12-italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Demi Cond' (lmsansdemicond10-oblique.otf) oblique normal demi condensed>) = 11.44
# 15:52:09:               findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-BoldItalic.ttf) italic normal bold condensed>) = 11.535
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant12-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant17-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed.ttf) normal normal 400 condensed>) = 2.25
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans12-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans8-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-ThinItalic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Semibold.ttf) normal normal semibold normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Nimbus Roman' (NimbusRoman-Bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'TeX Gyre Pagella Math' (texgyrepagella-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Nimbus Roman' (NimbusRoman-Italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Liberation Serif' (LiberationSerif-BoldItalic.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'P052' (P052-Roman.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Math' (latinmodern-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman8-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans17-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Thin.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman5-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre DejaVu Math' (texgyredejavu-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-MediumItalic.ttf) italic normal medium normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman17-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Nimbus Mono PS' (NimbusMonoPS-Italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Bonum Math' (texgyrebonum-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'URW Bookman' (URWBookman-LightItalic.otf) italic normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed-BoldItalic.ttf) italic normal bold condensed>) = 11.535
# 15:52:09:               findfont: score(<Font 'Nimbus Sans' (NimbusSans-Italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Liberation Serif' (LiberationSerif-Bold.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman5-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono' (lmmono10-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman10-bolditalic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans9-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Nimbus Roman' (NimbusRoman-Regular.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Medium.ttf) normal normal medium normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Noto Mono' (NotoMono-Regular.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans10-boldoblique.otf) oblique normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant9-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans10-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Nimbus Mono PS' (NimbusMonoPS-BoldItalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-bold.otf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Nimbus Sans Narrow' (NimbusSansNarrow-BoldOblique.otf) oblique normal bold condensed>) = 11.535
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-LightItalic.ttf) italic normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans12-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Liberation Mono' (LiberationMono-BoldItalic.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Liberation Sans' (LiberationSans-Regular.ttf) normal normal 400 normal>) = 4.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light Cond' (lmmonoltcond10-oblique.otf) oblique normal light condensed>) = 11.44
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-boldoblique.otf) oblique normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed-BoldOblique.ttf) oblique normal bold condensed>) = 3.535
# 15:52:09:               findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-HairlineItalic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Schola Math' (texgyreschola-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Heavy.ttf) normal normal heavy normal>) = 10.43
# 15:52:09:               findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Termes Math' (texgyretermes-math.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman10-italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans17-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Liberation Serif' (LiberationSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Nimbus Sans' (NimbusSans-Bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Sans' (lmsans10-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Liberation Sans' (LiberationSans-Bold.ttf) normal normal bold normal>) = 4.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-oblique.otf) oblique normal light normal>) = 11.24
# 15:52:09:               findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-regular.otf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'C059' (C059-Bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed-Bold.ttf) normal normal bold condensed>) = 2.535
# 15:52:09:               findfont: score(<Font 'Liberation Sans' (LiberationSans-BoldItalic.ttf) italic normal bold normal>) = 5.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop' (lmmonoprop10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'URW Gothic' (URWGothic-Book.otf) normal normal book normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'DejaVu Math TeX Gyre' (DejaVuMathTeXGyre.ttf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman7-italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman9-italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-BoldItalic.ttf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-bolditalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'P052' (P052-BoldItalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Z003' (Z003-MediumItalic.otf) italic normal medium normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Bold.ttf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman8-italic.otf) italic normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Droid Sans Fallback' (DroidSansFallbackFull.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman9-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'C059' (C059-BdIta.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Demi' (lmromandemi10-oblique.otf) oblique normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Liberation Sans' (LiberationSans-Italic.ttf) italic normal 400 normal>) = 5.05
# 15:52:09:               findfont: score(<Font 'Liberation Mono' (LiberationMono-Regular.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-Regular.ttf) normal normal 400 condensed>) = 10.25
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman12-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono' (lmmono12-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Caps' (lmmonocaps10-oblique.otf) oblique normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono' (lmmono9-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed.ttf) normal normal 400 condensed>) = 10.25
# 15:52:09:               findfont: score(<Font 'P052' (P052-Bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman8-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-regular.otf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Caps' (lmromancaps10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Dunhill' (lmromandunh10-oblique.otf) oblique normal roman normal>) = 11.145
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman6-bold.otf) normal normal roman normal>) = 10.145
# 15:52:09:               findfont: score(<Font 'Liberation Mono' (LiberationMono-Italic.ttf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Liberation Serif' (LiberationSerif-Regular.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'Nimbus Sans' (NimbusSans-BoldItalic.otf) italic normal bold normal>) = 11.335
# 15:52:09:               findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-italic.otf) italic normal 400 normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'URW Gothic' (URWGothic-BookOblique.otf) oblique normal book normal>) = 11.05
# 15:52:09:               findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed-Oblique.ttf) oblique normal 400 condensed>) = 3.25
# 15:52:09:               findfont: score(<Font 'Lato' (Lato-Hairline.ttf) normal normal 400 normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman Dunhill' (lmromandunh10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'Latin Modern Roman' (lmroman10-regular.otf) normal normal regular normal>) = 10.05
# 15:52:09:               findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-bold.otf) normal normal bold normal>) = 10.335
# 15:52:09:               findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-bold.otf) normal normal light normal>) = 10.24
# 15:52:09:               findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/home/artem/.conda/envs/ica_new/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 2.050000.

# %%
results[2]['Statistics']['Efficiency per Iteration']
# Out:
# OrderedDict([(0, 0.5083803905189288),
#              (1, 0.8721127072078818),
#              (2, 0.902746982296867),
#              (3, 0.9128866737766014),
#              (4, 0.9128866737766025),
#              (5, 0.9128866737766014),
#              (6, 0.9357784382230352),
#              (7, 0.9357784382230294),
#              (8, 0.9357784382230316),
#              (9, 0.9439172925977332)])

# %%
def _get_file_names(dir_file,Domain,Qinit,Qmax,Seed):
    Domain=Domain
    Qinit= Qinit
    Qmax= Qmax
    Seed = Seed
    my_dict={}
    
    for i in Domain:
        for l in Qinit:
            for k in Qmax:
                for j in Seed:
                    key_name=i+'_'+str(l)+'_'+str(k)+'_'+str(j)
                    instance = dir_file+i+'_'+str(l)+'_'+str(k)+'_'+str(j)+'_'+'*'
                    my_dict[key_name]=glob.glob(instance)

    my_dict = dict( [(k,v) for k,v in my_dict.items() if len(v)>0])
    return(my_dict)

def _retrieve_data(my_dict):
    mydict_data={}
    for key, value in my_dict.items():
        data=[]
        for i in my_dict[key]:
            tmp=load_result(i)
            data.append(tmp['result'])
        mydict_data[key] = pd.DataFrame.from_records(data)
    return(mydict_data)

def NN_Bidder_df(dict_nn,summary):
    seeds = list(dict_nn.keys())
    bidders = list(dict_nn[seeds[0]]['Main Economy'].keys())
    rounds= list(np.arange(0,len(dict_nn[seeds[0]]['Main Economy'][bidders[0]]),1))

    main_dict = {}
    if summary[0] =='Full':
        for seed in seeds:
            main_dict[seed]={}
            for bidder in bidders:
                main_dict[seed][bidder]={}
                for rond in rounds:
                    main_dict[seed][bidder][rond]=[]
                    for marginal,values in dict_nn[seed].items() :
                        try:
                            main_dict[seed][bidder][rond].append(dict_nn[seed][marginal][bidder][rond][2])
                        except:
                            pass
        return(pd.DataFrame.from_dict(main_dict))

                    
    elif summary[0]=='Compact':
        for bidder in bidders:
            main_dict[bidder]={}
            for rond in rounds:
                main_dict[bidder][rond]=[]
                for seed in seeds:
                    for marginal,values in dict_nn[seed].items():
                        try:
                            main_dict[bidder][rond].append(dict_nn[seed][marginal][bidder][rond][2])
                        except:
                            pass
    
        if summary[1]=='Average':
            summary_dict= pd.DataFrame({'Round':[],'Mean':[],'Std':[],'Type':[]})
            for bidder in bidders:
                for rond in rounds:
                    mean=np.array(main_dict[bidder][rond]).mean()
                    std=np.array(main_dict[bidder][rond]).std()
                    new_row= {'Round':rond,'Mean':mean,'Std':std,'Type':bidder}
                    summary_dict = summary_dict.append(new_row, ignore_index=True)
                    
            return(summary_dict)

        elif summary[1]=='Particular':
            summary_dict= pd.DataFrame({'Round':[],'Error':[],'Type':[]})
            for bidder in bidders:
                for rond in rounds:
                    tmp = main_dict[bidder][rond]
                    for i in range(len(tmp)):
                        new_row= {'Round':rond,'Error':tmp[i],'Type':bidder}
                        summary_dict = summary_dict.append(new_row, ignore_index=True)
                        
            return(summary_dict)                        
        elif summary[1]=='None':
                  
            return(pd.DataFrame.from_dict(main_dict))
        
def Eff_round(raw_dict,setting):
    seeds = list(raw_dict.keys())
    rounds= list(raw_dict[seeds[0]].keys())
    tpe= setting
    df= pd.DataFrame({'Round':[],'Efficiency':[],'Type':setting})
    for seed in seeds:
        for rond in rounds:
            new_row= {'Round':rond,'Efficiency':raw_dict[seed][rond],'Type':setting}
            df = df.append(new_row, ignore_index=True)    
    
    return(df)


def get_results(dir_file,Domain,Qinit,Qmax,Seed):
    Domain=Domain
    Qinit= Qinit
    Qmax= Qmax
    Seed = Seed
    my_dict={}
    
    my_dict=_get_file_names(dir_file,Domain,Qinit,Qmax,Seed)
    mydict_data=_retrieve_data(my_dict)
    
    return(mydict_data)

def get_summary(input_dict,criteria):
    my_dict={}
    if criteria=='Efficiency':
    
        for keys in input_dict.keys():
            my_dict[keys]=input_dict['Statistics'][0]['Efficiency per Iteration']
            
        return(pd.DataFrame.from_records(my_dict))
            
    elif criteria=='NN Losses':
            
        for keys in input_dict.keys():
            my_dict[keys]=input_dict[keys]['Statistics'][0]['NN Losses']
            
        return(my_dict)

        
    elif criteria=='Total Time':
            
        for keys in input_dict.keys():
            my_dict[keys]=[input_dict['Statistics'][0]['Total Time Elapsed']]
        
        return(pd.DataFrame.from_dict(my_dict))

# %%
#tensor-pytorch
Domain = ['GSVM']
Qinit= [30]
Qmax= [100]
Seed = np.arange(10,500,10)

dir_file_1 = './experiments/alper/Alloc/mip_alloc/gsvm_mip/'
dir_file_2 = './experiments/MLCA/Alloc/pytorch_alloc/GSVM_final/'
# dir_file_3 = './experiments/MLCA/Alloc/pytorch_alloc/sample_numbers/sample-100/'
# dir_file_4 = './experiments/MLCA/Alloc/pytorch_alloc/sample_numbers/sample-500/'
# dir_file_5 = './experiments/MLCA/Alloc/pytorch_alloc/sample_numbers/sample-1k/'


#file_1 = get_results(result_file_dir,['GSVM'],Qinit,Qmax,Seed)
#print(file_1)
#file_2 = get_results(dir_file_2,['GSVM'],Qinit,Qmax,Seed)
# file_3 = get_results(dir_file_3,['GSVM'],Qinit,Qmax,Seed)
# file_4 = get_results(dir_file_4,['GSVM'],Qinit,Qmax,Seed)
# file_5 = get_results(dir_file_5,['GSVM'],Qinit,Qmax,Seed)


df_file_1 = get_summary(result_file,criteria='Efficiency')
print(df_file_1)
#df_file_2=get_summary(file_2,criteria='Efficiency')
# df_file_3=get_summary(file_3,criteria='Efficiency')
# df_file_4=get_summary(file_4,criteria='Efficiency')
# df_file_5=get_summary(file_5,criteria='Efficiency')

eff_file_1 = Eff_round(df_file_1,'GSVM DL-ICA')
#eff_file_2 = Eff_round(df_file_2,'GSVM RL-ICA')
# eff_file_3 = Eff_round(df_file_3,'Sample Number 100')
# eff_file_4 = Eff_round(df_file_4,'Sample Number 500')
# eff_file_5 = Eff_round(df_file_5,'Sample Number 1000')

combined = eff_file_1.merge(eff_file_2,how='outer')
# combined = combined.merge(eff_file_3,how='outer')
# combined = combined.merge(eff_file_4,how='outer')
# combined = combined.merge(eff_file_5,how='outer')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-6c3f9763e5e1> in <module>
#      20
#      21
# ---> 22 df_file_1 = get_summary(result_file,criteria='Efficiency')
#      23 print(df_file_1)
#      24 #df_file_2=get_summary(file_2,criteria='Efficiency')
#
# <ipython-input-14-49558e0d208c> in get_summary(input_dict, criteria)
#     115
#     116         for keys in input_dict.keys():
# --> 117             my_dict[keys]=input_dict['Statistics'][0]['Efficiency per Iteration']
#     118
#     119         return(pd.DataFrame.from_records(my_dict))
#
# KeyError: 0

# %%
sns.catplot(x="Efficiency", y="Round", row="Type",
                kind="box", orient="h", height=2, aspect=4,
                data=combined)

sns.lineplot(
    data=combined,
    x="Round", y="Efficiency", hue="Type", err_style='bars',
    markers=True, dashes=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-563fa9969ba7> in <module>
#       1 sns.catplot(x="Efficiency", y="Round", row="Type",
#       2                 kind="box", orient="h", height=2, aspect=4,
# ----> 3                 data=combined)
#       4
#       5 sns.lineplot(
#
# NameError: name 'combined' is not defined

# %%
df_file_1 = get_summary(result_file,criteria='Total Time')
df_file_2 = get_summary(result_file,criteria='Total Time')


runtime_file_1=pd.to_timedelta(df_file_1.transpose()[0])
runtime_file_2=pd.to_timedelta(df_file_2.transpose()[0])



df_run_file_1 =pd.DataFrame({
    'Run Time(m)' : (runtime_file_1.astype('timedelta64[m]')).array,
    'Type' : 'DL-ICA'})
df_run_file_2 =pd.DataFrame({
    'Run Time(m)' : (runtime_file_2.astype('timedelta64[m]')).array,
    'Type' :'RL-ICA'})


frames = [df_run_file_1,df_run_file_2]

run_compact = pd.concat(frames)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-b7fdbd4808ed> in <module>
# ----> 1 df_file_1 = get_summary(result_file,criteria='Total Time')
#       2 df_file_2 = get_summary(result_file,criteria='Total Time')
#       3
#       4
#       5 runtime_file_1=pd.to_timedelta(df_file_1.transpose()[0])
#
# <ipython-input-39-8f8d90df06d2> in get_summary(input_dict, criteria)
#     130
#     131         for keys in input_dict.keys():
# --> 132             my_dict[keys]=[input_dict[keys]['Statistics'][0]['Total Time Elapsed']]
#     133
#     134         return(pd.DataFrame.from_dict(my_dict))
#
# KeyError: 'Statistics'

# %%
h=sns.displot(data=run_compact, x="Run Time(m)", col="Type", kde=False ,stat="density",common_norm=False)
